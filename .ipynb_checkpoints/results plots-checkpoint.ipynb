# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot(loss, title):
    plt.plot(loss[0], label='kl')
    plt.plot(loss[1], label='l')
    plt.plot(loss[2], label='r')       
    plt.legend()
    plt.savefig(f'./results/plots/{title}.png')
    plt.title(f'{title} loss')
    plt.show()

# %%
# adapted

kl = np.load('./results/vae_adapted/inception_kl_loss.npy')
l = np.load('./results/vae_adapted/inception_loss.npy')
r = np.load('./results/vae_adapted/inception_reconstruction_loss.npy')

plot([kl, l, r], 'Adapted Inception')

kl = np.load('./results/vae_adapted/mobilenet_kl_loss.npy')
l = np.load('./results/vae_adapted/mobilenet_loss.npy')
r = np.load('./results/vae_adapted/mobilenet_reconstruction_loss.npy')

plot([kl, l, r], 'Adapted Mobilenet')

kl = np.load('./results/vae_adapted/resnet_kl_loss.npy')
l = np.load('./results/vae_adapted/resnet_loss.npy')
r = np.load('./results/vae_adapted/resnet_reconstruction_loss.npy')

plot([kl, l, r], 'Adapted Resnet')

kl = np.load('./results/vae_adapted/vgg_kl_loss.npy')
l = np.load('./results/vae_adapted/vgg_loss.npy')
r = np.load('./results/vae_adapted/vgg_reconstruction_loss.npy')

plot([kl, l, r], 'Adapted VGG')

# %%
# injected
kl = np.load('./results/vae_injected/inception_kl_loss.npy')
l = np.load('./results/vae_injected/inception_loss.npy')
r = np.load('./results/vae_adapted/inception_reconstruction_loss.npy')

plot([kl, l, r], 'Injected Inception')

kl = np.load('./results/vae_injected/mobilenet_kl_loss.npy')
l = np.load('./results/vae_injected/mobilenet_loss.npy')
r = np.load('./results/vae_injected/mobilenet_reconstruction_loss.npy')

plot([kl, l, r], 'Injected Mobilenet')

kl = np.load('./results/vae_injected/resnet_kl_loss.npy')
l = np.load('./results/vae_injected/resnet_loss.npy')
r = np.load('./results/vae_injected/resnet_reconstruction_loss.npy')

plot([kl, l, r], 'Injected Resnet')

kl = np.load('./results/vae_injected/vgg_kl_loss.npy')
l = np.load('./results/vae_injected/vgg_loss.npy')
r = np.load('./results/vae_injected/vgg_reconstruction_loss.npy')

plot([kl, l, r], 'Injected VGG')

# %%
# vanilla
kl = np.load('./results/vae_vanilla/inception_kl_loss.npy')
l = np.load('./results/vae_vanilla/inception_loss.npy')
r = np.load('./results/vae_vanilla/inception_reconstruction_loss.npy')

plot([kl, l, r], 'Vanilla Inception')

kl = np.load('./results/vae_vanilla/mobilenet_kl_loss.npy')
l = np.load('./results/vae_vanilla/mobilenet_loss.npy')
r = np.load('./results/vae_vanilla/mobilenet_reconstruction_loss.npy')

plot([kl, l, r], 'Vanilla Mobilenet')

kl = np.load('./results/vae_vanilla/resnet_kl_loss.npy')
l = np.load('./results/vae_vanilla/resnet_loss.npy')
r = np.load('./results/vae_vanilla/resnet_reconstruction_loss.npy')

plot([kl, l, r], 'Vanilla Resnet')

kl = np.load('./results/vae_vanilla/vgg_kl_loss.npy')
l = np.load('./results/vae_vanilla/vgg_loss.npy')
r = np.load('./results/vae_vanilla/vgg_reconstruction_loss.npy')

plot([kl, l, r], 'Vanilla VGG')
