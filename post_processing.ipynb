# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
vae_vanilla_result = np.load('./results/vae_vanilla/reconstruction_loss.npy')
vae_adapted_result = np.load('./results/vae_adapted/loss.npy')
vae_injected_result = np.load('./results/vae_injected/loss.npy')
print(vae_vanilla_result.shape)
print(vae_vanilla_result)
plt.plot(range(100), vae_vanilla_result)
plt.plot(range(100), vae_adapted_result)
plt.plot(range(100), vae_injected_result)
plt.show()

# %%
inception_classification_train = np.load('./inception_classifier_history.npy')
mobilenet_classification_train = np.load('./mobilenet_classifier_history.npy')
vanilla_classification_train = np.load('./vae_vanilla_inception_classifier_history.npy')
adapted_classification_train = np.load('./vae_adapted_inception_classifier_history.npy')
injected_classification_train = np.load('./vae_injected_inception_classifier_history.npy')
plt.plot(inception_classification_train, label='Inception')
plt.plot(mobilenet_classification_train, label='Mobilenet')
plt.plot(vanilla_classification_train, label='VAE Vanilla')
plt.plot(adapted_classification_train, label='VAE Adapted')
plt.plot(injected_classification_train, label='VAE Injected')
plt.legend()
plt.show()
